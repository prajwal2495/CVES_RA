# %%
import pandas as pd
import numpy as np
import matplotlib
from sklearn.cluster import KMeans
from collections import defaultdict

# %%
from matplotlib import pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')

# %%
corpus = pd.read_csv("api_corpus.csv")
data = pd.read_json("corpus2.json")

corpus.head(5)
# Out:
#      id            cve project_name  \
# 0   912  CVE-2013-6665     chromium
# 1  1457  CVE-2017-5093     chromium
# 2  1471  CVE-2017-5107     chromium
# 3  1425  CVE-2017-5060     chromium
# 4   957  CVE-2014-1748     chromium
#
#                                          description  \
# 0  Heap-based buffer overflow in Chrome's resourc...
# 1  UI spoofing in Blink, a browser engine used in...
# 2  User information leak via SVG. By rendering a ...
# 3  URL spoofing in Omnibox. Certain Cyrillic char...
# 4  The scrollbar rectangles for images were not p...
#
#                                             mistakes
# 0  The vulnerabliity here was a pretty simple ove...
# 1  In my opinion, there were coding and design mi...
# 2                                                NaN
# 3                                                NaN
# 4  The main mistake that was made here was less o...

# %%
data.head(25)
# Out:
#       id             cve project_name  \
# 0   1037   CVE-2014-7948     chromium
# 1   1158   CVE-2015-6757     chromium
# 2   1489   CVE-2017-5125     chromium
# 3    184   CVE-2010-4488     chromium
# 4   1269   CVE-2016-1682     chromium
# 5   1560   CVE-2006-3747        httpd
# 6    394   CVE-2011-2845     chromium
# 7   1091   CVE-2015-1257     chromium
# 8    951   CVE-2014-1741     chromium
# 9   1437   CVE-2017-5071     chromium
# 10   190   CVE-2010-4494     chromium
# 11  1362  CVE-2017-15390     chromium
# 12  1075   CVE-2015-1241     chromium
# 13   350   CVE-2011-2786     chromium
# 14  1108   CVE-2015-1274     chromium
# 15   858   CVE-2013-2914     chromium
# 16  1128   CVE-2015-1295     chromium
# 17  1284   CVE-2016-1697     chromium
# 18   946   CVE-2014-1733     chromium
# 19   176   CVE-2010-4205     chromium
# 20  1494   CVE-2017-5130     chromium
# 21   576   CVE-2011-3961     chromium
# 22  1831   CVE-2018-1336       tomcat
# 23  1854   CVE-2014-7809       struts
# 24  1045   CVE-2015-1210     chromium
#
#                                           description  \
# 0   Google Chrome caches pages despite having an S...
# 1   Trying to access data in ServiceWorker after i...
# 2                 Embargoed. Heap overflow in Skia.\n
# 3   This bug involves an unhandled case in which t...
# 4   Checks to verify the content security policy (...
# 5   This was a vulnerability that affected people ...
# 6   An attacker can use this vulnerability to spoo...
# 7   The graphics module used by the Chromium engin...
# 8   There are a couple cases in lower level code t...
# 9                         Out of bounds read in V8.\n
# 10  There is a double free vulnerability in libxml...
# 11              Embargoed. URL Spoofing in Omnibox.\n
# 12  On mobile, click events were able to fire outs...
# 13  \nThe pop-up screen for speech-input-bubble in...
# 14  This vulnerability took advantage of Chrome's ...
# 15  In the color chooser dialog on Chrome before 3...
# 16  When opening a PDF file into chromium, the cli...
# 17  Attackers were able to create javascript code ...
# 18  The bug was in Chromium's Sandbox in the way t...
# 19  The vulnerability was in Google Chrome where t...
# 20             Embargoed. Heap overflow in libxml2.\n
# 21  Race condition in Google Chrome allows remote ...
# 22  Use of supplementary characters, such as those...
# 23  Due to an ineffective random number generator,...
# 24  When an exception is thrown in the DOM, the ex...
#
#                                              mistakes  \
# 0   I think that the vulenrability is interesting ...
# 1   The mistake made here was a basic C coding mis...
# 2                                                None
# 3   This could be a coding or design error, there ...
# 4   It seems as though the developer just didn't t...
# 5   It seems like the fault was in the code. The f...
# 6   The mistake here was that there wasn't proper ...
# 7   What ultimately led to this bug were assumptio...
# 8   This is another example of a minor coding mist...
# 9                                                None
# 10  Double free vulnerability is a common memory c...
# 11                                               None
# 12  This seems most like a requirements mistake. T...
# 13  This really seems to be a mix of requirements ...
# 14  This can be described as a requirements mistak...
# 15  The coding mistake was a pretty simple one. Th...
# 16  The vulnerability seemed to be caused by a lac...
# 17  This vulnerability was primarily the result of...
# 18  The biggest mistake made in causing this vulne...
# 19  The vulnerability was a simple oversight where...
# 20                                               None
# 21  The coding mistake that was made was not locki...
# 22  This was an implementation mistake. CWE-153 sa...
# 23  I would classify this issue as a simple coding...
# 24  This was a case in code, as this was a small h...
#
#                                              tag_list
# 0   [{'id': 8, 'tag': 'bounty'}, {'id': 95, 'tag':...
# 1   [{'id': 5, 'tag': 'lifetime-1y2y'}, {'id': 8, ...
# 2   [{'id': 14, 'tag': 'cwe-119'}, {'id': 357, 'ta...
# 3   [{'id': 3, 'tag': 'lifetime-90d180d'}, {'id': ...
# 4   [{'id': 1, 'tag': 'lifetime-30d'}, {'id': 8, '...
# 5   [{'id': 6, 'tag': 'lifetime-2y5y'}, {'id': 15,...
# 6   [{'id': 7, 'tag': 'lifetime-5y'}, {'id': 8, 't...
# 7   [{'id': 6, 'tag': 'lifetime-2y5y'}, {'id': 8, ...
# 8   [{'id': 7, 'tag': 'lifetime-5y'}, {'id': 8, 't...
# 9            [{'id': 357, 'tag': 'project-chromium'}]
# 10  [{'id': 94, 'tag': 'discover-automated'}, {'id...
# 11  [{'id': 11, 'tag': 'cwe-20'}, {'id': 357, 'tag...
# 12  [{'id': 3, 'tag': 'lifetime-90d180d'}, {'id': ...
# 13  [{'id': 4, 'tag': 'lifetime-180d1y'}, {'id': 9...
# 14  [{'id': 8, 'tag': 'bounty'}, {'id': 95, 'tag':...
# 15  [{'id': 5, 'tag': 'lifetime-1y2y'}, {'id': 8, ...
# 16  [{'id': 1, 'tag': 'lifetime-30d'}, {'id': 8, '...
# 17  [{'id': 4, 'tag': 'lifetime-180d1y'}, {'id': 8...
# 18  [{'id': 5, 'tag': 'lifetime-1y2y'}, {'id': 8, ...
# 19  [{'id': 2, 'tag': 'lifetime-3mo'}, {'id': 8, '...
# 20  [{'id': 43, 'tag': 'cwe-787'}, {'id': 357, 'ta...
# 21  [{'id': 5, 'tag': 'lifetime-1y2y'}, {'id': 8, ...
# 22  [{'id': 7, 'tag': 'lifetime-5y'}, {'id': 440, ...
# 23  [{'id': 7, 'tag': 'lifetime-5y'}, {'id': 488, ...
# 24  [{'id': 5, 'tag': 'lifetime-1y2y'}, {'id': 8, ...
